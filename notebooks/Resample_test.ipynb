# %%
import sys
import os

sys.path.append('../src/')

from read_data import DataObject
from constants import spend_categories
from dataframe_utilities import *

# %%
OVS1618 = DataObject(source = "OVS", version = "1618")
TVAE = DataObject(source = "Synthetic", version = "?", model = "TVAE")

upsample(TVAE.data, nrows = OVS1618.size[0] - TVAE.size[0])
# Out:
#       month  Mode of Transport (m1)  a1   a4   a5  r.int1  r.int2  b1a  b1b  \
# 5107      4                       1   1   54   31      48       3    2  1.0
# 5706     11                       1   1   79  187      25       4    1  NaN
# 9439      5                       3   1   57   94      27      10    1  NaN
# 6786      7                       1   1   79   29      32       3    2  1.0
# 9463      3                       1   1  123  213       2       3    1  NaN
# ...     ...                     ...  ..  ...  ...     ...     ...  ...  ...
# 7426      8                       3   1   79  102       2       4    1  2.0
# 7676      7                       1   1  123   99      14       2    1  1.0
# 4284     11                       1   1   65  212      20       2    2  NaN
# 8860      8                       1   1  123  102      20       6    1  3.0
# 611       6                       1   1   79   43      20       3    2  2.0
#
#       b2  ...  b12number_3_5_cat  b12number_7_8  b12number_7_8_cat  c8b_99  \
# 5107   1  ...                  1              0                  1       0
# 5706   1  ...                  1             -1                  1       0
# 9439   1  ...                  1              0                  1       0
# 6786   1  ...                  1              0                  1       0
# 9463   1  ...                  1             -1                  1       0
# ...   ..  ...                ...            ...                ...     ...
# 7426   1  ...                  1             -1                  1       0
# 7676   1  ...                  1              0                  1       0
# 4284   1  ...                  1              0                  1       0
# 8860   1  ...                  1             -1                  1       0
# 611    2  ...                  1             -1                  1       0
#
#       c8b_1  c8b_3  c8b_5  c8b_6  c8b_7  c8b_11
# 5107      1      0      0      0      0       0
# 5706      0      0      0      1      0       1
# 9439      0      0      1      0      0       0
# 6786      1      0      1      1      0       0
# 9463      0      0      1      1      0       0
# ...     ...    ...    ...    ...    ...     ...
# 7426      1      0      0      0      0       0
# 7676      1      0      1      0      0       0
# 4284      0      0      0      1      0       0
# 8860      0      0      0      0      0       0
# 611       0      0      1      0      1       0
#
# [56125 rows x 293 columns]

# %%
from visualizations import KDEPlot

KDEPlot((TVAE.data, upsample(TVAE.data, nrows = OVS1618.size[0] - TVAE.size[0])),
        spend_categories,
        labels = ["TVAE", "Resampled TVAE"])
