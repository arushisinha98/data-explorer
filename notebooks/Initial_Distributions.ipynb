# %%
import sys
import os

sys.path.append('../src/')

from read_data import DataObject
from constants import spend_categories
from visualizations import KDEPlot
from dataframe_utilities import get_filter_index, subgroup_sum, upsample

# %%
OVS1619 = DataObject(source = "OVS", version = "1619")
TVAE = DataObject(source = "Synthetic", version = "?", model = "TVAE")
TGAN = DataObject(source = "Synthetic", version = "?", model = "TGAN")
CTGAN = DataObject(source = "Synthetic", version = "?", model = "CTGAN")

# %%
print(OVS1619.size)
print(TVAE.size)
print(TGAN.size)
print(CTGAN.size)
# Out:
# (88731, 293)
# (9905, 293)
# (9905, 293)
# (9905, 293)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
import pandas as pd

# recode
recode_b10 = {0: '0 days',
              1: '1 day',
              2: '2 days',
              3: '3 days',
              4: '4 days',
              5: '5 days',
              6: '6 days',
              7: '7 days'}
# all others: greater than or equal to 8 days

recode_a4 = {3: 'American',
             25: 'Chinese',
             38: 'Emirati',
             39: 'English',
             57: 'Indian',
             65: 'Japanese',
             79: 'Malaysian',
             115: 'South Korean'}
# all others: other nationalities

def recode(input_df, colname, recode_dict, fill_label = ""):
    assert isinstance(input_df, pd.DataFrame), "Require input_df to be a pandas dataframe."
    assert colname in input_df.columns, "The column you wish to recode does not exist in input_df."
    assert isinstance(recode_dict, dict), "Require recode_dict to be specified as a dictionary."
    assert fill_label not in list(recode_dict.values()), f"'{fill_label}' is already present in the recode_dict. Please specify an unused filler."
    
    try:
        output_df = input_df.copy()
        for ii in output_df.index:
            item = output_df[colname][ii]
            if item in recode_dict.keys():
                output_df.loc[ii, colname] = recode_dict[item]
            else:
                output_df.loc[ii, colname] = fill_label
        return output_df
        
    except Exception as e:
        print("Failed to recode dataframe. Terminate.")
        current_dateTime = str(datetime.now())[0:19]
        print(current_dateTime + ': ' + str(e))

# %%
for data_object in (OVS1619, TVAE, TGAN, CTGAN):
    data_object.data = recode(data_object.data, 'b10', recode_b10, 'Greater than or equal to 8 days')
    data_object.data = recode(data_object.data, 'a4', recode_a4, 'Other Nationalities')

# %%
OVS1619.data[['month', 'Mode of Transport (m1)', 'b10', 'a4', 'a2.r.10l']].head(10)
# Out:
#    month  Mode of Transport (m1)                              b10  \
# 0      1                       1                           6 days
# 1      1                       1  Greater than or equal to 8 days
# 2      1                       1                           7 days
# 3      1                       1                           4 days
# 4      1                       1                           6 days
# 5      1                       1                           3 days
# 6      1                       1  Greater than or equal to 8 days
# 7      1                       1  Greater than or equal to 8 days
# 8      1                       1                           2 days
# 9      1                       1                           3 days
#
#                     a4  a2.r.10l
# 0               Indian         4
# 1               Indian         3
# 2               Indian         5
# 3              Chinese         6
# 4             American        10
# 5  Other Nationalities         5
# 6  Other Nationalities        10
# 7  Other Nationalities         5
# 8  Other Nationalities         4
# 9             Japanese         3

# %%
columns = spend_categories

n = 1
for PERM1 in OVS1619.data['Mode of Transport (m1)'].unique():
    for PERM2 in OVS1619.data['a2.r.10l'].unique():
        for PERM4 in OVS1619.data['b10'].unique():
            print(f"SUBGROUP #{n}:\n\
            Mode of Transport == {PERM1}\n\
            Age Group == {PERM2}\n\
            Length of Stay == {PERM4}")
            n += 1

            value_filters = {'Mode of Transport (m1)': PERM1,
                             'a2.r.10l': PERM2,
                             'b10': PERM4}

            # filter data
            df1 = OVS1619.data.iloc[get_filter_index(OVS1619.data, value_filters)]
            df2 = TVAE.data.iloc[get_filter_index(TVAE.data, value_filters)]
            df3 = TGAN.data.iloc[get_filter_index(TGAN.data, value_filters)]
            df4 = CTGAN.data.iloc[get_filter_index(CTGAN.data, value_filters)]
            
            
            if df1.shape[0] > 30 and df2.shape[0] > 30 and df3.shape[0] > 30 and df4.shape[0] > 30:
                input_dfs = (df1, df2, df4, df4)
                labels = ['OVS1619', 'TVAE', 'TGAN', 'CTGAN']
                KDEPlot(input_dfs, columns, labels,
                        figname = f"Mode{PERM1}_Age{PERM2}_LOS{PERM4}",
                        save = True)
# Out:
# SUBGROUP #1:
#             Mode of Transport == 1
#             Age Group == 4
#             Length of Stay == 6 days
# SUBGROUP #2:
#             Mode of Transport == 1
#             Age Group == 4
#             Length of Stay == Greater than or equal to 8 days
# SUBGROUP #3:
#             Mode of Transport == 1
#             Age Group == 4
#             Length of Stay == 7 days
# SUBGROUP #4:
#             Mode of Transport == 1
#             Age Group == 4
#             Length of Stay == 4 days
# SUBGROUP #5:
#             Mode of Transport == 1
#             Age Group == 4
#             Length of Stay == 3 days
# SUBGROUP #6:
#             Mode of Transport == 1
#             Age Group == 4
#             Length of Stay == 2 days
# SUBGROUP #7:
#             Mode of Transport == 1
#             Age Group == 4
#             Length of Stay == 0 days
# SUBGROUP #8:
#             Mode of Transport == 1
#             Age Group == 4
#             Length of Stay == 5 days
# SUBGROUP #9:
#             Mode of Transport == 1
#             Age Group == 4
#             Length of Stay == 1 day
# SUBGROUP #10:
#             Mode of Transport == 1
#             Age Group == 3
#             Length of Stay == 6 days
# SUBGROUP #11:
#             Mode of Transport == 1
#             Age Group == 3
#             Length of Stay == Greater than or equal to 8 days
# SUBGROUP #12:
#             Mode of Transport == 1
#             Age Group == 3
#             Length of Stay == 7 days
# SUBGROUP #13:
#             Mode of Transport == 1
#             Age Group == 3
#             Length of Stay == 4 days
# SUBGROUP #14:
#             Mode of Transport == 1
#             Age Group == 3
#             Length of Stay == 3 days
# SUBGROUP #15:
#             Mode of Transport == 1
#             Age Group == 3
#             Length of Stay == 2 days
# SUBGROUP #16:
#             Mode of Transport == 1
#             Age Group == 3
#             Length of Stay == 0 days
# SUBGROUP #17:
#             Mode of Transport == 1
#             Age Group == 3
#             Length of Stay == 5 days
# SUBGROUP #18:
#             Mode of Transport == 1
#             Age Group == 3
#             Length of Stay == 1 day
# SUBGROUP #19:
#             Mode of Transport == 1
#             Age Group == 5
#             Length of Stay == 6 days
# SUBGROUP #20:
#             Mode of Transport == 1
#             Age Group == 5
#             Length of Stay == Greater than or equal to 8 days
# SUBGROUP #21:
#             Mode of Transport == 1
#             Age Group == 5
#             Length of Stay == 7 days
# SUBGROUP #22:
#             Mode of Transport == 1
#             Age Group == 5
#             Length of Stay == 4 days
# SUBGROUP #23:
#             Mode of Transport == 1
#             Age Group == 5
#             Length of Stay == 3 days
# SUBGROUP #24:
#             Mode of Transport == 1
#             Age Group == 5
#             Length of Stay == 2 days
# SUBGROUP #25:
#             Mode of Transport == 1
#             Age Group == 5
#             Length of Stay == 0 days
# SUBGROUP #26:
#             Mode of Transport == 1
#             Age Group == 5
#             Length of Stay == 5 days
# SUBGROUP #27:
#             Mode of Transport == 1
#             Age Group == 5
#             Length of Stay == 1 day
# SUBGROUP #28:
#             Mode of Transport == 1
#             Age Group == 6
#             Length of Stay == 6 days
# SUBGROUP #29:
#             Mode of Transport == 1
#             Age Group == 6
#             Length of Stay == Greater than or equal to 8 days
# SUBGROUP #30:
#             Mode of Transport == 1
#             Age Group == 6
#             Length of Stay == 7 days
# SUBGROUP #31:
#             Mode of Transport == 1
#             Age Group == 6
#             Length of Stay == 4 days
# SUBGROUP #32:
#             Mode of Transport == 1
#             Age Group == 6
#             Length of Stay == 3 days
# SUBGROUP #33:
#             Mode of Transport == 1
#             Age Group == 6
#             Length of Stay == 2 days
# SUBGROUP #34:
#             Mode of Transport == 1
#             Age Group == 6
#             Length of Stay == 0 days
# SUBGROUP #35:
#             Mode of Transport == 1
#             Age Group == 6
#             Length of Stay == 5 days
# SUBGROUP #36:
#             Mode of Transport == 1
#             Age Group == 6
#             Length of Stay == 1 day
# SUBGROUP #37:
#             Mode of Transport == 1
#             Age Group == 10
#             Length of Stay == 6 days
# SUBGROUP #38:
#             Mode of Transport == 1
#             Age Group == 10
#             Length of Stay == Greater than or equal to 8 days
# SUBGROUP #39:
#             Mode of Transport == 1
#             Age Group == 10
#             Length of Stay == 7 days
# SUBGROUP #40:
#             Mode of Transport == 1
#             Age Group == 10
#             Length of Stay == 4 days
# SUBGROUP #41:
#             Mode of Transport == 1
#             Age Group == 10
#             Length of Stay == 3 days
# SUBGROUP #42:
#             Mode of Transport == 1
#             Age Group == 10
#             Length of Stay == 2 days
# SUBGROUP #43:
#             Mode of Transport == 1
#             Age Group == 10
#             Length of Stay == 0 days
# SUBGROUP #44:
#             Mode of Transport == 1
#             Age Group == 10
#             Length of Stay == 5 days
# SUBGROUP #45:
#             Mode of Transport == 1
#             Age Group == 10
#             Length of Stay == 1 day
# SUBGROUP #46:
#             Mode of Transport == 1
#             Age Group == 1
#             Length of Stay == 6 days
# SUBGROUP #47:
#             Mode of Transport == 1
#             Age Group == 1
#             Length of Stay == Greater than or equal to 8 days
# SUBGROUP #48:
#             Mode of Transport == 1
#             Age Group == 1
#             Length of Stay == 7 days
# SUBGROUP #49:
#             Mode of Transport == 1
#             Age Group == 1
#             Length of Stay == 4 days
# SUBGROUP #50:
#             Mode of Transport == 1
#             Age Group == 1
#             Length of Stay == 3 days
# SUBGROUP #51:
#             Mode of Transport == 1
#             Age Group == 1
#             Length of Stay == 2 days
# SUBGROUP #52:
#             Mode of Transport == 1
#             Age Group == 1
#             Length of Stay == 0 days
# SUBGROUP #53:
#             Mode of Transport == 1
#             Age Group == 1
#             Length of Stay == 5 days
# SUBGROUP #54:
#             Mode of Transport == 1
#             Age Group == 1
#             Length of Stay == 1 day
# SUBGROUP #55:
#             Mode of Transport == 1
#             Age Group == 9
#             Length of Stay == 6 days
# SUBGROUP #56:
#             Mode of Transport == 1
#             Age Group == 9
#             Length of Stay == Greater than or equal to 8 days
# SUBGROUP #57:
#             Mode of Transport == 1
#             Age Group == 9
#             Length of Stay == 7 days
# SUBGROUP #58:
#             Mode of Transport == 1
#             Age Group == 9
#             Length of Stay == 4 days
# SUBGROUP #59:
#             Mode of Transport == 1
#             Age Group == 9
#             Length of Stay == 3 days
# SUBGROUP #60:
#             Mode of Transport == 1
#             Age Group == 9
#             Length of Stay == 2 days
# SUBGROUP #61:
#             Mode of Transport == 1
#             Age Group == 9
#             Length of Stay == 0 days
# SUBGROUP #62:
#             Mode of Transport == 1
#             Age Group == 9
#             Length of Stay == 5 days
# SUBGROUP #63:
#             Mode of Transport == 1
#             Age Group == 9
#             Length of Stay == 1 day
# SUBGROUP #64:
#             Mode of Transport == 1
#             Age Group == 2
#             Length of Stay == 6 days
# SUBGROUP #65:
#             Mode of Transport == 1
#             Age Group == 2
#             Length of Stay == Greater than or equal to 8 days
# SUBGROUP #66:
#             Mode of Transport == 1
#             Age Group == 2
#             Length of Stay == 7 days
# SUBGROUP #67:
#             Mode of Transport == 1
#             Age Group == 2
#             Length of Stay == 4 days
# SUBGROUP #68:
#             Mode of Transport == 1
#             Age Group == 2
#             Length of Stay == 3 days
# SUBGROUP #69:
#             Mode of Transport == 1
#             Age Group == 2
#             Length of Stay == 2 days
# SUBGROUP #70:
#             Mode of Transport == 1
#             Age Group == 2
#             Length of Stay == 0 days
# SUBGROUP #71:
#             Mode of Transport == 1
#             Age Group == 2
#             Length of Stay == 5 days
# SUBGROUP #72:
#             Mode of Transport == 1
#             Age Group == 2
#             Length of Stay == 1 day
# SUBGROUP #73:
#             Mode of Transport == 1
#             Age Group == 8
#             Length of Stay == 6 days
# SUBGROUP #74:
#             Mode of Transport == 1
#             Age Group == 8
#             Length of Stay == Greater than or equal to 8 days
# SUBGROUP #75:
#             Mode of Transport == 1
#             Age Group == 8
#             Length of Stay == 7 days
# SUBGROUP #76:
#             Mode of Transport == 1
#             Age Group == 8
#             Length of Stay == 4 days
# SUBGROUP #77:
#             Mode of Transport == 1
#             Age Group == 8
#             Length of Stay == 3 days
# SUBGROUP #78:
#             Mode of Transport == 1
#             Age Group == 8
#             Length of Stay == 2 days
# SUBGROUP #79:
#             Mode of Transport == 1
#             Age Group == 8
#             Length of Stay == 0 days
# SUBGROUP #80:
#             Mode of Transport == 1
#             Age Group == 8
#             Length of Stay == 5 days
# SUBGROUP #81:
#             Mode of Transport == 1
#             Age Group == 8
#             Length of Stay == 1 day
# SUBGROUP #82:
#             Mode of Transport == 1
#             Age Group == 7
#             Length of Stay == 6 days
# SUBGROUP #83:
#             Mode of Transport == 1
#             Age Group == 7
#             Length of Stay == Greater than or equal to 8 days
# SUBGROUP #84:
#             Mode of Transport == 1
#             Age Group == 7
#             Length of Stay == 7 days
# SUBGROUP #85:
#             Mode of Transport == 1
#             Age Group == 7
#             Length of Stay == 4 days
# SUBGROUP #86:
#             Mode of Transport == 1
#             Age Group == 7
#             Length of Stay == 3 days
# SUBGROUP #87:
#             Mode of Transport == 1
#             Age Group == 7
#             Length of Stay == 2 days
# SUBGROUP #88:
#             Mode of Transport == 1
#             Age Group == 7
#             Length of Stay == 0 days
# SUBGROUP #89:
#             Mode of Transport == 1
#             Age Group == 7
#             Length of Stay == 5 days
# SUBGROUP #90:
#             Mode of Transport == 1
#             Age Group == 7
#             Length of Stay == 1 day
# SUBGROUP #91:
#             Mode of Transport == 3
#             Age Group == 4
#             Length of Stay == 6 days
# SUBGROUP #92:
#             Mode of Transport == 3
#             Age Group == 4
#             Length of Stay == Greater than or equal to 8 days
# SUBGROUP #93:
#             Mode of Transport == 3
#             Age Group == 4
#             Length of Stay == 7 days
# SUBGROUP #94:
#             Mode of Transport == 3
#             Age Group == 4
#             Length of Stay == 4 days
# SUBGROUP #95:
#             Mode of Transport == 3
#             Age Group == 4
#             Length of Stay == 3 days
# SUBGROUP #96:
#             Mode of Transport == 3
#             Age Group == 4
#             Length of Stay == 2 days
# SUBGROUP #97:
#             Mode of Transport == 3
#             Age Group == 4
#             Length of Stay == 0 days
# SUBGROUP #98:
#             Mode of Transport == 3
#             Age Group == 4
#             Length of Stay == 5 days
# SUBGROUP #99:
#             Mode of Transport == 3
#             Age Group == 4
#             Length of Stay == 1 day
# SUBGROUP #100:
#             Mode of Transport == 3
#             Age Group == 3
#             Length of Stay == 6 days
# SUBGROUP #101:
#             Mode of Transport == 3
#             Age Group == 3
#             Length of Stay == Greater than or equal to 8 days
# SUBGROUP #102:
#             Mode of Transport == 3
#             Age Group == 3
#             Length of Stay == 7 days
# SUBGROUP #103:
#             Mode of Transport == 3
#             Age Group == 3
#             Length of Stay == 4 days
# SUBGROUP #104:
#             Mode of Transport == 3
#             Age Group == 3
#             Length of Stay == 3 days
# SUBGROUP #105:
#             Mode of Transport == 3
#             Age Group == 3
#             Length of Stay == 2 days
# SUBGROUP #106:
#             Mode of Transport == 3
#             Age Group == 3
#             Length of Stay == 0 days
# SUBGROUP #107:
#             Mode of Transport == 3
#             Age Group == 3
#             Length of Stay == 5 days
# SUBGROUP #108:
#             Mode of Transport == 3
#             Age Group == 3
#             Length of Stay == 1 day
# SUBGROUP #109:
#             Mode of Transport == 3
#             Age Group == 5
#             Length of Stay == 6 days
# SUBGROUP #110:
#             Mode of Transport == 3
#             Age Group == 5
#             Length of Stay == Greater than or equal to 8 days
# SUBGROUP #111:
#             Mode of Transport == 3
#             Age Group == 5
#             Length of Stay == 7 days
# SUBGROUP #112:
#             Mode of Transport == 3
#             Age Group == 5
#             Length of Stay == 4 days
# SUBGROUP #113:
#             Mode of Transport == 3
#             Age Group == 5
#             Length of Stay == 3 days
# SUBGROUP #114:
#             Mode of Transport == 3
#             Age Group == 5
#             Length of Stay == 2 days
# SUBGROUP #115:
#             Mode of Transport == 3
#             Age Group == 5
#             Length of Stay == 0 days
# SUBGROUP #116:
#             Mode of Transport == 3
#             Age Group == 5
#             Length of Stay == 5 days
# SUBGROUP #117:
#             Mode of Transport == 3
#             Age Group == 5
#             Length of Stay == 1 day
# SUBGROUP #118:
#             Mode of Transport == 3
#             Age Group == 6
#             Length of Stay == 6 days
# SUBGROUP #119:
#             Mode of Transport == 3
#             Age Group == 6
#             Length of Stay == Greater than or equal to 8 days
# SUBGROUP #120:
#             Mode of Transport == 3
#             Age Group == 6
#             Length of Stay == 7 days
# SUBGROUP #121:
#             Mode of Transport == 3
#             Age Group == 6
#             Length of Stay == 4 days
# SUBGROUP #122:
#             Mode of Transport == 3
#             Age Group == 6
#             Length of Stay == 3 days
# SUBGROUP #123:
#             Mode of Transport == 3
#             Age Group == 6
#             Length of Stay == 2 days
# SUBGROUP #124:
#             Mode of Transport == 3
#             Age Group == 6
#             Length of Stay == 0 days
# SUBGROUP #125:
#             Mode of Transport == 3
#             Age Group == 6
#             Length of Stay == 5 days
# SUBGROUP #126:
#             Mode of Transport == 3
#             Age Group == 6
#             Length of Stay == 1 day
# SUBGROUP #127:
#             Mode of Transport == 3
#             Age Group == 10
#             Length of Stay == 6 days
# SUBGROUP #128:
#             Mode of Transport == 3
#             Age Group == 10
#             Length of Stay == Greater than or equal to 8 days
# SUBGROUP #129:
#             Mode of Transport == 3
#             Age Group == 10
#             Length of Stay == 7 days
# SUBGROUP #130:
#             Mode of Transport == 3
#             Age Group == 10
#             Length of Stay == 4 days
# SUBGROUP #131:
#             Mode of Transport == 3
#             Age Group == 10
#             Length of Stay == 3 days
# SUBGROUP #132:
#             Mode of Transport == 3
#             Age Group == 10
#             Length of Stay == 2 days
# SUBGROUP #133:
#             Mode of Transport == 3
#             Age Group == 10
#             Length of Stay == 0 days
# SUBGROUP #134:
#             Mode of Transport == 3
#             Age Group == 10
#             Length of Stay == 5 days
# SUBGROUP #135:
#             Mode of Transport == 3
#             Age Group == 10
#             Length of Stay == 1 day
# SUBGROUP #136:
#             Mode of Transport == 3
#             Age Group == 1
#             Length of Stay == 6 days
# SUBGROUP #137:
#             Mode of Transport == 3
#             Age Group == 1
#             Length of Stay == Greater than or equal to 8 days
# SUBGROUP #138:
#             Mode of Transport == 3
#             Age Group == 1
#             Length of Stay == 7 days
# SUBGROUP #139:
#             Mode of Transport == 3
#             Age Group == 1
#             Length of Stay == 4 days
# SUBGROUP #140:
#             Mode of Transport == 3
#             Age Group == 1
#             Length of Stay == 3 days
# SUBGROUP #141:
#             Mode of Transport == 3
#             Age Group == 1
#             Length of Stay == 2 days
# SUBGROUP #142:
#             Mode of Transport == 3
#             Age Group == 1
#             Length of Stay == 0 days
# SUBGROUP #143:
#             Mode of Transport == 3
#             Age Group == 1
#             Length of Stay == 5 days
# SUBGROUP #144:
#             Mode of Transport == 3
#             Age Group == 1
#             Length of Stay == 1 day
# SUBGROUP #145:
#             Mode of Transport == 3
#             Age Group == 9
#             Length of Stay == 6 days
# SUBGROUP #146:
#             Mode of Transport == 3
#             Age Group == 9
#             Length of Stay == Greater than or equal to 8 days
# SUBGROUP #147:
#             Mode of Transport == 3
#             Age Group == 9
#             Length of Stay == 7 days
# SUBGROUP #148:
#             Mode of Transport == 3
#             Age Group == 9
#             Length of Stay == 4 days
# SUBGROUP #149:
#             Mode of Transport == 3
#             Age Group == 9
#             Length of Stay == 3 days
# SUBGROUP #150:
#             Mode of Transport == 3
#             Age Group == 9
#             Length of Stay == 2 days
# SUBGROUP #151:
#             Mode of Transport == 3
#             Age Group == 9
#             Length of Stay == 0 days
# SUBGROUP #152:
#             Mode of Transport == 3
#             Age Group == 9
#             Length of Stay == 5 days
# SUBGROUP #153:
#             Mode of Transport == 3
#             Age Group == 9
#             Length of Stay == 1 day
# SUBGROUP #154:
#             Mode of Transport == 3
#             Age Group == 2
#             Length of Stay == 6 days
# SUBGROUP #155:
#             Mode of Transport == 3
#             Age Group == 2
#             Length of Stay == Greater than or equal to 8 days
# SUBGROUP #156:
#             Mode of Transport == 3
#             Age Group == 2
#             Length of Stay == 7 days
# SUBGROUP #157:
#             Mode of Transport == 3
#             Age Group == 2
#             Length of Stay == 4 days
# SUBGROUP #158:
#             Mode of Transport == 3
#             Age Group == 2
#             Length of Stay == 3 days
# SUBGROUP #159:
#             Mode of Transport == 3
#             Age Group == 2
#             Length of Stay == 2 days
# SUBGROUP #160:
#             Mode of Transport == 3
#             Age Group == 2
#             Length of Stay == 0 days
# SUBGROUP #161:
#             Mode of Transport == 3
#             Age Group == 2
#             Length of Stay == 5 days
# SUBGROUP #162:
#             Mode of Transport == 3
#             Age Group == 2
#             Length of Stay == 1 day
# SUBGROUP #163:
#             Mode of Transport == 3
#             Age Group == 8
#             Length of Stay == 6 days
# SUBGROUP #164:
#             Mode of Transport == 3
#             Age Group == 8
#             Length of Stay == Greater than or equal to 8 days
# SUBGROUP #165:
#             Mode of Transport == 3
#             Age Group == 8
#             Length of Stay == 7 days
# SUBGROUP #166:
#             Mode of Transport == 3
#             Age Group == 8
#             Length of Stay == 4 days
# SUBGROUP #167:
#             Mode of Transport == 3
#             Age Group == 8
#             Length of Stay == 3 days
# SUBGROUP #168:
#             Mode of Transport == 3
#             Age Group == 8
#             Length of Stay == 2 days
# SUBGROUP #169:
#             Mode of Transport == 3
#             Age Group == 8
#             Length of Stay == 0 days
# SUBGROUP #170:
#             Mode of Transport == 3
#             Age Group == 8
#             Length of Stay == 5 days
# SUBGROUP #171:
#             Mode of Transport == 3
#             Age Group == 8
#             Length of Stay == 1 day
# SUBGROUP #172:
#             Mode of Transport == 3
#             Age Group == 7
#             Length of Stay == 6 days
# SUBGROUP #173:
#             Mode of Transport == 3
#             Age Group == 7
#             Length of Stay == Greater than or equal to 8 days
# SUBGROUP #174:
#             Mode of Transport == 3
#             Age Group == 7
#             Length of Stay == 7 days
# SUBGROUP #175:
#             Mode of Transport == 3
#             Age Group == 7
#             Length of Stay == 4 days
# SUBGROUP #176:
#             Mode of Transport == 3
#             Age Group == 7
#             Length of Stay == 3 days
# SUBGROUP #177:
#             Mode of Transport == 3
#             Age Group == 7
#             Length of Stay == 2 days
# SUBGROUP #178:
#             Mode of Transport == 3
#             Age Group == 7
#             Length of Stay == 0 days
# SUBGROUP #179:
#             Mode of Transport == 3
#             Age Group == 7
#             Length of Stay == 5 days
# SUBGROUP #180:
#             Mode of Transport == 3
#             Age Group == 7
#             Length of Stay == 1 day
# SUBGROUP #181:
#             Mode of Transport == 2
#             Age Group == 4
#             Length of Stay == 6 days
# SUBGROUP #182:
#             Mode of Transport == 2
#             Age Group == 4
#             Length of Stay == Greater than or equal to 8 days
# SUBGROUP #183:
#             Mode of Transport == 2
#             Age Group == 4
#             Length of Stay == 7 days
# SUBGROUP #184:
#             Mode of Transport == 2
#             Age Group == 4
#             Length of Stay == 4 days
# SUBGROUP #185:
#             Mode of Transport == 2
#             Age Group == 4
#             Length of Stay == 3 days
# SUBGROUP #186:
#             Mode of Transport == 2
#             Age Group == 4
#             Length of Stay == 2 days
# SUBGROUP #187:
#             Mode of Transport == 2
#             Age Group == 4
#             Length of Stay == 0 days
# SUBGROUP #188:
#             Mode of Transport == 2
#             Age Group == 4
#             Length of Stay == 5 days
# SUBGROUP #189:
#             Mode of Transport == 2
#             Age Group == 4
#             Length of Stay == 1 day
# SUBGROUP #190:
#             Mode of Transport == 2
#             Age Group == 3
#             Length of Stay == 6 days
# SUBGROUP #191:
#             Mode of Transport == 2
#             Age Group == 3
#             Length of Stay == Greater than or equal to 8 days
# SUBGROUP #192:
#             Mode of Transport == 2
#             Age Group == 3
#             Length of Stay == 7 days
# SUBGROUP #193:
#             Mode of Transport == 2
#             Age Group == 3
#             Length of Stay == 4 days
# SUBGROUP #194:
#             Mode of Transport == 2
#             Age Group == 3
#             Length of Stay == 3 days
# SUBGROUP #195:
#             Mode of Transport == 2
#             Age Group == 3
#             Length of Stay == 2 days
# SUBGROUP #196:
#             Mode of Transport == 2
#             Age Group == 3
#             Length of Stay == 0 days
# SUBGROUP #197:
#             Mode of Transport == 2
#             Age Group == 3
#             Length of Stay == 5 days
# SUBGROUP #198:
#             Mode of Transport == 2
#             Age Group == 3
#             Length of Stay == 1 day
# SUBGROUP #199:
#             Mode of Transport == 2
#             Age Group == 5
#             Length of Stay == 6 days
# SUBGROUP #200:
#             Mode of Transport == 2
#             Age Group == 5
#             Length of Stay == Greater than or equal to 8 days
# SUBGROUP #201:
#             Mode of Transport == 2
#             Age Group == 5
#             Length of Stay == 7 days
# SUBGROUP #202:
#             Mode of Transport == 2
#             Age Group == 5
#             Length of Stay == 4 days
# SUBGROUP #203:
#             Mode of Transport == 2
#             Age Group == 5
#             Length of Stay == 3 days
# SUBGROUP #204:
#             Mode of Transport == 2
#             Age Group == 5
#             Length of Stay == 2 days
# SUBGROUP #205:
#             Mode of Transport == 2
#             Age Group == 5
#             Length of Stay == 0 days
# SUBGROUP #206:
#             Mode of Transport == 2
#             Age Group == 5
#             Length of Stay == 5 days
# SUBGROUP #207:
#             Mode of Transport == 2
#             Age Group == 5
#             Length of Stay == 1 day
# SUBGROUP #208:
#             Mode of Transport == 2
#             Age Group == 6
#             Length of Stay == 6 days
# SUBGROUP #209:
#             Mode of Transport == 2
#             Age Group == 6
#             Length of Stay == Greater than or equal to 8 days
# SUBGROUP #210:
#             Mode of Transport == 2
#             Age Group == 6
#             Length of Stay == 7 days
# SUBGROUP #211:
#             Mode of Transport == 2
#             Age Group == 6
#             Length of Stay == 4 days
# SUBGROUP #212:
#             Mode of Transport == 2
#             Age Group == 6
#             Length of Stay == 3 days
# SUBGROUP #213:
#             Mode of Transport == 2
#             Age Group == 6
#             Length of Stay == 2 days
# SUBGROUP #214:
#             Mode of Transport == 2
#             Age Group == 6
#             Length of Stay == 0 days
# SUBGROUP #215:
#             Mode of Transport == 2
#             Age Group == 6
#             Length of Stay == 5 days
# SUBGROUP #216:
#             Mode of Transport == 2
#             Age Group == 6
#             Length of Stay == 1 day
# SUBGROUP #217:
#             Mode of Transport == 2
#             Age Group == 10
#             Length of Stay == 6 days
# SUBGROUP #218:
#             Mode of Transport == 2
#             Age Group == 10
#             Length of Stay == Greater than or equal to 8 days
# SUBGROUP #219:
#             Mode of Transport == 2
#             Age Group == 10
#             Length of Stay == 7 days
# SUBGROUP #220:
#             Mode of Transport == 2
#             Age Group == 10
#             Length of Stay == 4 days
# SUBGROUP #221:
#             Mode of Transport == 2
#             Age Group == 10
#             Length of Stay == 3 days
# SUBGROUP #222:
#             Mode of Transport == 2
#             Age Group == 10
#             Length of Stay == 2 days
# SUBGROUP #223:
#             Mode of Transport == 2
#             Age Group == 10
#             Length of Stay == 0 days
# SUBGROUP #224:
#             Mode of Transport == 2
#             Age Group == 10
#             Length of Stay == 5 days
# SUBGROUP #225:
#             Mode of Transport == 2
#             Age Group == 10
#             Length of Stay == 1 day
# SUBGROUP #226:
#             Mode of Transport == 2
#             Age Group == 1
#             Length of Stay == 6 days
# SUBGROUP #227:
#             Mode of Transport == 2
#             Age Group == 1
#             Length of Stay == Greater than or equal to 8 days
# SUBGROUP #228:
#             Mode of Transport == 2
#             Age Group == 1
#             Length of Stay == 7 days
# SUBGROUP #229:
#             Mode of Transport == 2
#             Age Group == 1
#             Length of Stay == 4 days
# SUBGROUP #230:
#             Mode of Transport == 2
#             Age Group == 1
#             Length of Stay == 3 days
# SUBGROUP #231:
#             Mode of Transport == 2
#             Age Group == 1
#             Length of Stay == 2 days
# SUBGROUP #232:
#             Mode of Transport == 2
#             Age Group == 1
#             Length of Stay == 0 days
# SUBGROUP #233:
#             Mode of Transport == 2
#             Age Group == 1
#             Length of Stay == 5 days
# SUBGROUP #234:
#             Mode of Transport == 2
#             Age Group == 1
#             Length of Stay == 1 day
# SUBGROUP #235:
#             Mode of Transport == 2
#             Age Group == 9
#             Length of Stay == 6 days
# SUBGROUP #236:
#             Mode of Transport == 2
#             Age Group == 9
#             Length of Stay == Greater than or equal to 8 days
# SUBGROUP #237:
#             Mode of Transport == 2
#             Age Group == 9
#             Length of Stay == 7 days
# SUBGROUP #238:
#             Mode of Transport == 2
#             Age Group == 9
#             Length of Stay == 4 days
# SUBGROUP #239:
#             Mode of Transport == 2
#             Age Group == 9
#             Length of Stay == 3 days
# SUBGROUP #240:
#             Mode of Transport == 2
#             Age Group == 9
#             Length of Stay == 2 days
# SUBGROUP #241:
#             Mode of Transport == 2
#             Age Group == 9
#             Length of Stay == 0 days
# SUBGROUP #242:
#             Mode of Transport == 2
#             Age Group == 9
#             Length of Stay == 5 days
# SUBGROUP #243:
#             Mode of Transport == 2
#             Age Group == 9
#             Length of Stay == 1 day
# SUBGROUP #244:
#             Mode of Transport == 2
#             Age Group == 2
#             Length of Stay == 6 days
# SUBGROUP #245:
#             Mode of Transport == 2
#             Age Group == 2
#             Length of Stay == Greater than or equal to 8 days
# SUBGROUP #246:
#             Mode of Transport == 2
#             Age Group == 2
#             Length of Stay == 7 days
# SUBGROUP #247:
#             Mode of Transport == 2
#             Age Group == 2
#             Length of Stay == 4 days
# SUBGROUP #248:
#             Mode of Transport == 2
#             Age Group == 2
#             Length of Stay == 3 days
# SUBGROUP #249:
#             Mode of Transport == 2
#             Age Group == 2
#             Length of Stay == 2 days
# SUBGROUP #250:
#             Mode of Transport == 2
#             Age Group == 2
#             Length of Stay == 0 days
# SUBGROUP #251:
#             Mode of Transport == 2
#             Age Group == 2
#             Length of Stay == 5 days
# SUBGROUP #252:
#             Mode of Transport == 2
#             Age Group == 2
#             Length of Stay == 1 day
# SUBGROUP #253:
#             Mode of Transport == 2
#             Age Group == 8
#             Length of Stay == 6 days
# SUBGROUP #254:
#             Mode of Transport == 2
#             Age Group == 8
#             Length of Stay == Greater than or equal to 8 days
# SUBGROUP #255:
#             Mode of Transport == 2
#             Age Group == 8
#             Length of Stay == 7 days
# SUBGROUP #256:
#             Mode of Transport == 2
#             Age Group == 8
#             Length of Stay == 4 days
# SUBGROUP #257:
#             Mode of Transport == 2
#             Age Group == 8
#             Length of Stay == 3 days
# SUBGROUP #258:
#             Mode of Transport == 2
#             Age Group == 8
#             Length of Stay == 2 days
# SUBGROUP #259:
#             Mode of Transport == 2
#             Age Group == 8
#             Length of Stay == 0 days
# SUBGROUP #260:
#             Mode of Transport == 2
#             Age Group == 8
#             Length of Stay == 5 days
# SUBGROUP #261:
#             Mode of Transport == 2
#             Age Group == 8
#             Length of Stay == 1 day
# SUBGROUP #262:
#             Mode of Transport == 2
#             Age Group == 7
#             Length of Stay == 6 days
# SUBGROUP #263:
#             Mode of Transport == 2
#             Age Group == 7
#             Length of Stay == Greater than or equal to 8 days
# SUBGROUP #264:
#             Mode of Transport == 2
#             Age Group == 7
#             Length of Stay == 7 days
# SUBGROUP #265:
#             Mode of Transport == 2
#             Age Group == 7
#             Length of Stay == 4 days
# SUBGROUP #266:
#             Mode of Transport == 2
#             Age Group == 7
#             Length of Stay == 3 days
# SUBGROUP #267:
#             Mode of Transport == 2
#             Age Group == 7
#             Length of Stay == 2 days
# SUBGROUP #268:
#             Mode of Transport == 2
#             Age Group == 7
#             Length of Stay == 0 days
# SUBGROUP #269:
#             Mode of Transport == 2
#             Age Group == 7
#             Length of Stay == 5 days
# SUBGROUP #270:
#             Mode of Transport == 2
#             Age Group == 7
#             Length of Stay == 1 day

# %%
import pandas as pd

resampled_TVAE = pd.concat([TVAE.data,
                           upsample(TVAE.data, nrows = OVS1619.size[0] - TVAE.size[0])],
                           ignore_index = True)
resampled_TGAN = pd.concat([TGAN.data,
                           upsample(TGAN.data, nrows = OVS1619.size[0] - TGAN.size[0])],
                           ignore_index = True)
resampled_CTGAN = pd.concat([CTGAN.data,
                            upsample(CTGAN.data, nrows = OVS1619.size[0] - CTGAN.size[0])],
                            ignore_index = True)

print(OVS1619.size)
print(resampled_TVAE.shape)
print(resampled_TGAN.shape)
print(resampled_CTGAN.shape)
# Out:
# (88731, 293)
# (88731, 293)
# (88731, 293)
# (88731, 293)

# %%
df1 = OVS1619.data
df2 = resampled_TVAE
df3 = resampled_TGAN
df4 = resampled_CTGAN

n = 1
for PERM1 in OVS1619.data['Mode of Transport (m1)'].unique():
    for PERM2 in OVS1619.data['a2.r.10l'].unique():
        for PERM4 in OVS1619.data['b10'].unique():
            print(f"SUBGROUP #{n}:\n\
            Mode of Transport == {PERM1}\n\
            Age Group == {PERM2}\n\
            Length of Stay == {PERM4}")
            n += 1

            value_filters = {'Mode of Transport (m1)': PERM1,
                             'a2.r.10l': PERM2,
                             'b10': PERM4}
            
            # get subgroup sums
            print(f"\n\
            Target |\t{np.round(subgroup_sum(df1, spend_categories[0], value_filters),2)}\t{np.round(subgroup_sum(df1, spend_categories[1], value_filters),2)}\t{np.round(subgroup_sum(df1, spend_categories[2], value_filters),2)}\t{np.round(subgroup_sum(df1, spend_categories[3], value_filters),2)}\t{np.round(subgroup_sum(df1, spend_categories[4], value_filters),2)}\n\
            ---------------------------------------------------------------------------------\n\
            TVAE   |\t{np.round(subgroup_sum(df2, spend_categories[0], value_filters),2)}\t{np.round(subgroup_sum(df2, spend_categories[1], value_filters),2)}\t{np.round(subgroup_sum(df2, spend_categories[2], value_filters),2)}\t{np.round(subgroup_sum(df2, spend_categories[3], value_filters),2)}\t{np.round(subgroup_sum(df2, spend_categories[4], value_filters),2)}\n\
            TGAN   |\t{np.round(subgroup_sum(df3, spend_categories[0], value_filters),2)}\t{np.round(subgroup_sum(df3, spend_categories[1], value_filters),2)}\t{np.round(subgroup_sum(df3, spend_categories[2], value_filters),2)}\t{np.round(subgroup_sum(df3, spend_categories[3], value_filters),2)}\t{np.round(subgroup_sum(df3, spend_categories[4], value_filters),2)}\n\
            CTGAN  |\t{np.round(subgroup_sum(df4, spend_categories[0], value_filters),2)}\t{np.round(subgroup_sum(df4, spend_categories[1], value_filters),2)}\t{np.round(subgroup_sum(df4, spend_categories[2], value_filters),2)}\t{np.round(subgroup_sum(df4, spend_categories[3], value_filters),2)}\t{np.round(subgroup_sum(df4, spend_categories[4], value_filters),2)}\n")
# Out:
# SUBGROUP #1:
#             Mode of Transport == 1
#             Age Group == 4
#             Length of Stay == 6 days
#
#             Target |	286088.95	124003.58	38026.22	62546.88	118807.01
#             ---------------------------------------------------------------------------------
#             TVAE   |	395516.27	205492.58	66051.04	115568.89	204283.54
#             TGAN   |	176104.81	124592.09	31681.97	56008.03	87648.86
#             CTGAN  |	195865.06	128934.39	32658.67	63608.75	95774.93
#
# SUBGROUP #2:
#             Mode of Transport == 1
#             Age Group == 4
#             Length of Stay == Greater than or equal to 8 days
#
#             Target |	396066.45	164040.59	56671.95	55655.24	171866.26
#             ---------------------------------------------------------------------------------
#             TVAE   |	205762.06	110977.25	35736.11	51767.83	105104.84
#             TGAN   |	56467.53	51152.73	15882.99	38386.16	83401.87
#             CTGAN  |	61090.44	56583.52	17064.21	41622.69	77898.88
#
# SUBGROUP #3:
#             Mode of Transport == 1
#             Age Group == 4
#             Length of Stay == 7 days
#
#             Target |	180264.98	82245.24	27681.36	49512.78	79449.67
#             ---------------------------------------------------------------------------------
#             TVAE   |	3693.13	1461.68	492.06	-6.38	1474.76
#             TGAN   |	26117.04	28356.41	8550.51	5479.25	36902.92
#             CTGAN  |	15517.99	18661.69	5541.84	4618.49	29380.32
#
# SUBGROUP #4:
#             Mode of Transport == 1
#             Age Group == 4
#             Length of Stay == 4 days
#
#             Target |	1296898.06	579564.44	161313.73	387221.9	563813.63
#             ---------------------------------------------------------------------------------
#             TVAE   |	788600.68	331298.96	100714.86	204114.32	319144.64
#             TGAN   |	790229.63	346580.97	129923.7	247320.54	445841.87
#             CTGAN  |	772369.11	346189.0	122410.35	223273.34	429409.63
#
# SUBGROUP #5:
#             Mode of Transport == 1
#             Age Group == 4
#             Length of Stay == 3 days

# %% [markdown]
# #### LOS >= 8 days

# %%
columns = spend_categories

for PERM4 in OVS1619.data['b10'].unique():
    print(f"Length of Stay == {PERM4}")
    
    value_filters = {'b10': PERM4}

    # filter data
    df1 = OVS1619.data.iloc[get_filter_index(OVS1619.data, value_filters)]
    df2 = TVAE.data.iloc[get_filter_index(TVAE.data, value_filters)]
    df3 = TGAN.data.iloc[get_filter_index(TGAN.data, value_filters)]
    df4 = CTGAN.data.iloc[get_filter_index(CTGAN.data, value_filters)]
            
            
    input_dfs = (df1, df2, df4, df4)
    labels = ['OVS1619', 'TVAE', 'TGAN', 'CTGAN']
    KDEPlot(input_dfs, columns, labels,
            figname = f"LOS{PERM4}",
            save = True)
# Out:
# Length of Stay == 6 days
# Length of Stay == Greater than or equal to 8 days
# Length of Stay == 7 days
# Length of Stay == 4 days
# Length of Stay == 3 days
# Length of Stay == 2 days
# Length of Stay == 0 days
# Length of Stay == 5 days
# Length of Stay == 1 day
