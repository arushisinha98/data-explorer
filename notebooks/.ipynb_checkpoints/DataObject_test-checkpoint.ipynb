# %%
import sys
import os

sys.path.append('../src/')

# %%
from read_data import DataObject
from constants import spend_categories

# %%
OVS1618 = DataObject(source = "OVS", version = "1618")

# %%
print(OVS1618)
# Out:
# OVS Data: 1618.
# Model: None
# Size: (66030, 293)
# Last Updated: 2022-10-22 11:04:47

# %%
OVS1618.data[spend_categories].describe()
# Out:
#        Expenditure on Accommodation (c4.tot.new)  \
# count                               66030.000000
# mean                                  435.044752
# std                                   538.704690
# min                                    -1.000000
# 25%                                    -1.000000
# 50%                                   300.000000
# 75%                                   650.000000
# max                                  7005.000000
#
#        Expenditure on F&B (c6.tot.new)  Expenditure on Transport (c7.tot.new)  \
# count                     66030.000000                           66030.000000
# mean                        194.530211                              61.695835
# std                         212.677285                              67.416126
# min                          -1.000000                              -1.000000
# 25%                          20.000000                               6.000000
# ...

# %%
OVS1618.data[spend_categories].isna().sum()
# Out:
# Expenditure on Accommodation (c4.tot.new)                   0
# Expenditure on F&B (c6.tot.new)                             0
# Expenditure on Transport (c7.tot.new)                       0
# Expenditure on Sightseeing & Entertainment (c10.tot.new)    0
# Expenditure on Shopping (t7.m.any)                          0
# dtype: int64

# %%
OVS1619 = DataObject(source = "OVS", version = "1619")
print(OVS1619)
# Out:
# OVS Data: 1619.
# Model: None
# Size: (88731, 293)
# Last Updated: 2023-09-02 19:08:28.042578

# %%
OVS1619.data[spend_categories].describe()
# Out:
#        Expenditure on Accommodation (c4.tot.new)  \
# count                               88731.000000
# mean                                  435.010696
# std                                   552.057881
# min                                    -1.000000
# 25%                                    -1.000000
# 50%                                   283.257760
# 75%                                   650.000000
# max                                  6455.120000
#
#        Expenditure on F&B (c6.tot.new)  Expenditure on Transport (c7.tot.new)  \
# count                     88731.000000                           88731.000000
# mean                        191.902221                              61.087144
# std                         219.284678                              71.649527
# min                          -1.000000                              -1.000000
# 25%                          20.000000                              -1.000000
# ...

# %%
OVS1619.data[spend_categories].isna().sum()
# Out:
# Expenditure on Accommodation (c4.tot.new)                   0
# Expenditure on F&B (c6.tot.new)                             0
# Expenditure on Transport (c7.tot.new)                       0
# Expenditure on Sightseeing & Entertainment (c10.tot.new)    0
# Expenditure on Shopping (t7.m.any)                          0
# dtype: int64

# %%
SYN = DataObject(source = "Synthetic", version = "?", model = "TVAE")

# %%
print(SYN)
# Out:
# Synthetic Data: ?.
# Model: TVAE
# Size: (9905, 293)
# Last Updated: 2021-03-06 06:00:25

# %%
SYN.data[spend_categories].describe()
# Out:
#        Expenditure on Accommodation (c4.tot.new)  \
# count                                9905.000000
# mean                                  455.573912
# std                                   498.861720
# min                                   -16.441691
# 25%                                    59.135051
# 50%                                   319.827726
# 75%                                   685.570239
# max                                  4020.696016
#
#        Expenditure on F&B (c6.tot.new)  Expenditure on Transport (c7.tot.new)  \
# count                      9905.000000                            9905.000000
# mean                        200.658171                              63.041834
# std                         206.185187                              65.497540
# min                         -15.576365                              -2.728649
# 25%                          38.618478                              11.758427
# ...

# %%
SYN.data[spend_categories].isna().sum()
# Out:
# Expenditure on Accommodation (c4.tot.new)                   0
# Expenditure on F&B (c6.tot.new)                             0
# Expenditure on Transport (c7.tot.new)                       0
# Expenditure on Sightseeing & Entertainment (c10.tot.new)    0
# Expenditure on Shopping (t7.m.any)                          0
# dtype: int64

# %%
SYN = DataObject(source = "Synthetic", version = "?", model = "TGAN")
print(SYN)
# Out:
# Synthetic Data: ?.
# Model: TGAN
# Size: (9905, 293)
# Last Updated: 2021-03-10 07:14:09

# %%
SYN.data[spend_categories].describe()
# Out:
#        Expenditure on Accommodation (c4.tot.new)  \
# count                                9905.000000
# mean                                  400.589996
# std                                   507.531685
# min                                   -19.044811
# 25%                                     1.749782
# 50%                                   229.989046
# 75%                                   607.172891
# max                                  4197.206430
#
#        Expenditure on F&B (c6.tot.new)  Expenditure on Transport (c7.tot.new)  \
# count                      9905.000000                            9905.000000
# mean                        182.406509                              61.121120
# std                         205.938834                              64.228269
# min                         -20.589018                              -3.230518
# 25%                          15.269283                              12.288829
# ...

# %%
SYN.data[spend_categories].isna().sum()
# Out:
# Expenditure on Accommodation (c4.tot.new)                   0
# Expenditure on F&B (c6.tot.new)                             0
# Expenditure on Transport (c7.tot.new)                       0
# Expenditure on Sightseeing & Entertainment (c10.tot.new)    0
# Expenditure on Shopping (t7.m.any)                          0
# dtype: int64

# %%
SYN = DataObject(source = "Synthetic", version = "?", model = "CTGAN")
print(SYN)
# Out:
# Synthetic Data: ?.
# Model: CTGAN
# Size: (9905, 293)
# Last Updated: 2021-03-10 07:14:09

# %%
SYN.data[spend_categories].describe()
# Out:
#        Expenditure on Accommodation (c4.tot.new)  \
# count                                9905.000000
# mean                                  400.589996
# std                                   507.531685
# min                                   -19.044811
# 25%                                     1.749782
# 50%                                   229.989046
# 75%                                   607.172891
# max                                  4197.206430
#
#        Expenditure on F&B (c6.tot.new)  Expenditure on Transport (c7.tot.new)  \
# count                      9905.000000                            9905.000000
# mean                        182.406509                              61.121120
# std                         205.938834                              64.228269
# min                         -20.589018                              -3.230518
# 25%                          15.269283                              12.288829
# ...

# %%
SYN.data[spend_categories].isna().sum()
# Out:
# Expenditure on Accommodation (c4.tot.new)                   0
# Expenditure on F&B (c6.tot.new)                             0
# Expenditure on Transport (c7.tot.new)                       0
# Expenditure on Sightseeing & Entertainment (c10.tot.new)    0
# Expenditure on Shopping (t7.m.any)                          0
# dtype: int64
